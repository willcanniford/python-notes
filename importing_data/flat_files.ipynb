# %% [markdown]
# # Importing flat files
# Flat files are an important part of the data analysis and data science workflow and a common way to both store and transfer data between people and systems. The most common format that I've come across is the `.csv` format which can be easily handled using the `pandas` library.

# %%
import pandas as pd # Import pandas

path_to_file = '../data/craft-cans/beers.csv'
beers = pd.read_csv(path_to_file)

# %% [markdown]
# At its most basic level, that is it. We now have access to the information that is stored in the `beers.csv` csv file in the data section of this repository.

# %%
beers.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
beers.describe()
# Out:
#         Unnamed: 0          abv          ibu           id   brewery_id  \
# count  2410.000000  2348.000000  1405.000000  2410.000000  2410.000000
# mean   1204.500000     0.059773    42.713167  1431.113278   231.749793
# std     695.851397     0.013542    25.954066   752.459975   157.685604
# min       0.000000     0.001000     4.000000     1.000000     0.000000
# 25%     602.250000     0.050000    21.000000   808.250000    93.000000
# 50%    1204.500000     0.056000    35.000000  1453.500000   205.000000
# 75%    1806.750000     0.067000    64.000000  2075.750000   366.000000
# max    2409.000000     0.128000   138.000000  2692.000000   557.000000
#
#             ounces
# count  2410.000000
# mean     13.592241
# std       2.352204
# min       8.400000
# 25%      12.000000
# 50%      12.000000
# 75%      16.000000
# max      32.000000

# %% [markdown]
# Having had more of a look, we can see that the first column (`Unnamed: 0`) most likely just represents a primary index for the beers table. We could either remove it, or we could specify that when we load the data in the first place.

# %%
beers2 = pd.read_csv(path_to_file, index_col=0)
beers2.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %% [markdown]
# In the above instance, I specified that I wanted the first column to become the index of the DataFrame using the index of the column: `0` = first column.
#
# Let's say, for instance, that we wanted the name column to be the index column when we loaded the data in. We could specify it by the name of the column, rather than the index, as shown below.

# %%
beers3 = pd.read_csv(path_to_file, index_col='name')
beers3.head()
# Out:
#                      Unnamed: 0    abv  ibu    id  \
# name
# Pub Beer                      0  0.050  NaN  1436
# Devil's Cup                   1  0.066  NaN  2265
# Rise of the Phoenix           2  0.071  NaN  2264
# Sinister                      3  0.090  NaN  2263
# Sex and Candy                 4  0.075  NaN  2262
#
#                                               style  brewery_id  ounces
# name
# Pub Beer                        American Pale Lager         408    12.0
# Devil's Cup                 American Pale Ale (APA)         177    12.0
# Rise of the Phoenix                    American IPA         177    12.0
# Sinister             American Double / Imperial IPA         177    12.0
# Sex and Candy                          American IPA         177    12.0

# %% [markdown]
# As a side note, we could have simply reindexed `beers2` to achieve effectively the same result without having to reload the data.

# %%
beers2.set_index('name').head()
# Out:
#                        abv  ibu    id                           style  \
# name
# Pub Beer             0.050  NaN  1436             American Pale Lager
# Devil's Cup          0.066  NaN  2265         American Pale Ale (APA)
# Rise of the Phoenix  0.071  NaN  2264                    American IPA
# Sinister             0.090  NaN  2263  American Double / Imperial IPA
# Sex and Candy        0.075  NaN  2262                    American IPA
#
#                      brewery_id  ounces
# name
# Pub Beer                    408    12.0
# Devil's Cup                 177    12.0
# Rise of the Phoenix         177    12.0
# Sinister                    177    12.0
# Sex and Candy               177    12.0
